# %%
import sys 
sys.path.append("..") 
from pubmedkit.baseline import baseline_to_dict, baseline_to_pd
from glob import glob

# %%
dir = '../testdata/updatefiles/'

file1 = dir+'pubmed24n1220.xml.gz'

# %%
print(file1)
# Out:
# ../testdata/updatefiles/pubmed24n1220.xml.gz

# %%
ref = baseline_to_dict(file1)

# %%
import pandas as pd

# %%
ref_df = pd.DataFrame.from_dict(ref).T

# %%
ref_df
# Out:
#               pmid                                              title  \
# 1025          1025  Isolation and purification of cytokinin bindin...
# 1250          1250  Purification and properties of isoenzymes of c...
# 433            433  Uptake, translocation, and metabolism of tirpa...
# 1314          1314                  The soybean answer to food costs.
# 3                3  Metal substitutions incarbonic anhydrase: a ha...
# ...            ...                                                ...
# 10998539  10998539  Functional studies using antibodies against or...
# 10998544  10998544  Nocistatin: a novel neuropeptide encoded by th...
# 10998538  10998538     Effects of supraspinal orphanin FQ/nociceptin.
# 10998545  10998545  Integrity of tritiated orphanin FQ/nociceptin:...
# 10998547  10998547  Nociceptin differentially affects morphine-ind...
#
#                                                    abstract  \
# 1025
# 1250      Two isoenzymes of an NADP+ -dependent cinnamyl...
# 433
# 1314
# 3
# ...                                                     ...
# 10998539  Orphanin FQ/nociceptin (OFQ) is a recently dis...
# 10998544  We identified a novel neuropeptide and named i...
# 10998538  The first reported behavioral action of the en...
# 10998545  In the course of establishing a reliable and r...
# 10998547  The effects induced by nociceptin on morphine-...
#
#                                                     journal pubdate  \
# 1025      Biochemical and biophysical research communica...    1975
# 1250                       European journal of biochemistry    1975
# 433              Journal of agricultural and food chemistry    1975
# 1314                           Dimensions in health service    1976
# 3         Biochemical and biophysical research communica...    1975
# ...                                                     ...     ...
# 10998539                                           Peptides    2000
# 10998544                                           Peptides    2000
# 10998538                                           Peptides    2000
# 10998545                                           Peptides    2000
# 10998547                                           Peptides    2000
#
#                                           publication_types  \
# 1025                                D016428:Journal Article
# 1250                                D016428:Journal Article
# 433       D016428:Journal Article; D013487:Research Supp...
# 1314                                D016428:Journal Article
# 3         D016428:Journal Article; D013487:Research Supp...
# ...                                                     ...
# 10998539                            D016428:Journal Article
# 10998544  D016428:Journal Article; D013485:Research Supp...
# 10998538  D016428:Journal Article; D013487:Research Supp...
# 10998545  D003160:Comparative Study; D016428:Journal Art...
# 10998547                            D016428:Journal Article
#
#                                                     authors  \
# 1025                             Takegami|T|T|;Yoshida|K|K|
# 1250                           Wyrambik|D|D|;Grisebach|H|H|
# 433                            Hill|J E|JE|;Krieger|R I|RI|
# 1314                                      Stoughton|T C|TC|
# 3                              Smith|R J|RJ|;Bryant|R G|RG|
# ...                                                     ...
# 10998539                           Tian|J H|JH|;Han|J S|JS|
# 10998544                       Okuda-Ashitaka|E|E|;Ito|S|S|
# 10998538                       Grisel|J E|JE|;Mogil|J S|JS|
# 10998545  Quigley|D I|DI|;Arttamangkul|S|S|;Allen|R G|RG...
# 10998547                   Di Giannuario|A|A|;Pieretti|S|S|
#
#                                          doi        version
# 1025            10.1016/0006-291x(75)90881-5  pubmed24n1220
# 1250      10.1111/j.1432-1033.1975.tb02418.x  pubmed24n1220
# 433                      10.1021/jf60202a047  pubmed24n1220
# 1314                                          pubmed24n1220
# 3               10.1016/0006-291x(75)90498-2  pubmed24n1220
# ...                                      ...            ...
# 10998539       10.1016/s0196-9781(00)00242-4  pubmed24n1220
# 10998544       10.1016/s0196-9781(00)00247-3  pubmed24n1220
# 10998538       10.1016/s0196-9781(00)00236-9  pubmed24n1220
# 10998545       10.1016/s0196-9781(00)00248-5  pubmed24n1220
# 10998547       10.1016/s0196-9781(00)00250-3  pubmed24n1220
#
# [30000 rows x 9 columns]

# %%
ref_df2 = baseline_to_pd(file1)
