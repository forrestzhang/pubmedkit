# %%
import pandas as pd
import pickle

# %%
# df = pd.read_pickle('../testdata/test_baseline_filter.pkl')

# %%
data = pickle.load(open('../testdata/test_baseline_filter.pkl', 'rb'))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            pmid                                              title  \
# 0      34727520  An expansion of the non-coding genome and its ...
# 1      36109497  Transcriptional dynamics of murine motor neuro...
# 2      37897505  Deletion of adipocyte NOS3 potentiates high-fa...
# 3      38113256  Somatic mutations of MLL4/COMPASS induce cytop...
# 4      38113262  Distinct guard cell-specific remodeling of chr...
# ...         ...                                                ...
# 19852  39166482  Rapid profiling of transcription factor-cofact...
# 19853  39182558  Fibrillarin reprograms glucose metabolism by d...
# 19854  39197582  MAZ promotes thyroid cancer progression by dri...
# 19855  39216548  YBX1 as a therapeutic target to suppress the L...
# 19856  39271656  Exploring the transcriptional cooperation betw...
#
#                                                 abstract  \
# 0      Proper assembly and function of the nervous sy...
# ...
